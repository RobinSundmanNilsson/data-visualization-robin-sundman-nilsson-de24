# %% [markdown]
# ## 0. Tell a story from immigration

# %% [markdown]
# ## Lets improve "exercise_1_0_original.png"

# %% [markdown]
# ## a) Remove clutter from this visualization such as top spine and right spine. Also change the unit to thousands with a prefix K.

# %%
import pandas as pd

df = pd.read_csv("data/1900-census-immigrant-pop-metro.csv")

df.head()
# Out:
#         City         State  Error Total foreign born  Africa  \
# 0      Akron          Ohio      0              7,127     4.0
# 1     Albany      New York     55             17,718     3.0
# 2  Allegheny  Pennsylvania      0             30,216     4.0
# 3  Allentown  Pennsylvania      3              2,991     NaN
# 4    Altoona  Pennsylvania     65              3,301     2.0
#
#    Asia (except China, Japan, and India) Atlantic Islands Australia Austria  \
# 0                                    NaN              NaN         1     190
# 1                                   39.0                4        13     106
# 2                                    5.0                2         8   3,929
# 3                                    1.0              NaN         2     337
# 4                                    7.0              NaN       NaN      57
#
#   Belgium  ... Scotland South America Spain  Sweden Switzerland Turkey Wales  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 50 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   City                                         161 non-null    object
#  1   State                                        161 non-null    object
#  2   Error                                        161 non-null    int64
#  3   Total foreign born                           161 non-null    object
#  4   Africa                                       120 non-null    float64
#  5   Asia (except China, Japan, and India)        133 non-null    float64
#  6   Atlantic Islands                             99 non-null     object
#  7   Australia                                    136 non-null    object
#  8   Austria                                      161 non-null    object
# ...

# %%
df_nordic = df[["Sweden", "Norway", "Denmark", "Finland", "Total foreign born", "State"]]
df_nordic.head()
# Out:
#   Sweden Norway Denmark Finland Total foreign born         State
# 0    200     59     105       1              7,127          Ohio
# 1     65     12      21       3             17,718      New York
# 2    186      9      15       5             30,216  Pennsylvania
# 3      5      2       5     NaN              2,991  Pennsylvania
# 4     32      4       5       3              3,301  Pennsylvania

# %%
df_nordic = df_nordic.fillna("0")

# %%
columns = ["Sweden", "Norway", "Denmark", "Finland", "Total foreign born"]

for col in columns:
    df_nordic[col] = df_nordic[col].str.replace(",", "").astype(int)

# %%
df_nordic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sweden              161 non-null    int64
#  1   Norway              161 non-null    int64
#  2   Denmark             161 non-null    int64
#  3   Finland             161 non-null    int64
#  4   Total foreign born  161 non-null    int64
#  5   State               161 non-null    object
# dtypes: int64(5), object(1)
# memory usage: 7.7+ KB

# %%
import duckdb

df_nordic_summary = duckdb.query(
    """--sql
    SELECT
        State,
        SUM(Sweden) AS Sweden,
        SUM(Norway) AS Norway,
        SUM(Denmark) AS Denmark,
        SUM(Finland) AS Finland,
    FROM
        df_nordic
    WHERE
        State IN ('Illinois', 'Minnesota', 'New York')
    GROUP BY
        State
    """
).df()

# %%
df_nordic_summary = df_nordic_summary.set_index("State")
df_nordic_summary = df_nordic_summary.loc[["Illinois", "Minnesota", "New York"]]
df_nordic_summary
# Out:
#             Sweden   Norway  Denmark  Finland
# State
# Illinois   57158.0  22300.0  10374.0    447.0
# Minnesota  34984.0  17087.0   2975.0   1101.0
# New York   29961.0  11752.0   6186.0   3764.0

# %% [markdown]
# ## b) Left align the xlabel, top align the ylabel and left align the title

# %% [markdown]
# ## c) Use contrast to focus the attention to what you want the audience to see

# %% [markdown]
# ## d) Choose a story to tell and change the labels and title accordingly

# %% [markdown]
# ## e) You can choose several different stories to tell and depending on which one you choose, the visualization might look differently in terms of what parts are annotated, what parts are highlighted etc.
